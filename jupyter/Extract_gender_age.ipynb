# %%
import requests
import json
import datetime as dt
from hdfs import InsecureClient

# %%
client = InsecureClient('http://localhost:9870', user='big')

# %% [markdown]
# ### api실행함수/기준일자 함수정의

# %%
def execute_rest_api(method, url, headers, params):
    if method == 'get':
        res = requests.get(url, params=params, headers=headers, verify = False)
    elif method == 'post':
        res = requests.post(url, params=params, headers=headers, verify = False)
        
    if res == None or res.status_code != 200:
        raise Exception('응답코드 : ' + str(res.status_code))
    
    return res.text

def cal_std_day(before_day):   
    x = dt.datetime.now() - dt.timedelta(before_day)
    year = x.year
    month = x.month if x.month >= 10 else '0'+ str(x.month)
    day = x.day if x.day >= 10 else '0'+ str(x.day)  
    return str(year)+ str(month)+str(day)

# %% [markdown]
# ### API 호출

# %%
# api 호출
# url = "https://data.iros.go.kr/rp/ds/selectDatasetInqDetl.do"
# service_key = '90555d6ea59f4c6bb4132fa2da1f65ca'
# file_dir = '/realestate_data/gender_age/'

def create_params():
    url = "https://data.iros.go.kr/rp/ds/selectDatasetInqDetl.do"
    service_key = '90555d6ea59f4c6bb4132fa2da1f65ca'
    file_dir = '/realestate_data/gender_age/'
    data={
        'pageIndex':'1'
        ,'sort_cond':''
        ,'sort_ord':''
        ,'ris_menu_seq':'0000000007'
        ,'title':'%EB%B6%80%EB%8F%99%EC%82%B0 %EC%86%8C%EC%9C%A0%EA%B6%8C %EC%B7%A8%EB%93%9D%ED%98%84%ED%99%A9(%EC%A7%80%EC%97%AD%2C %EC%86%8C%EC%9C%A0%EC%9E%90%EB%B3%84)'
        ,'search_date':'201701'
        ,'rdata_seq':'0000000252'
        ,'search_type':'037001'
        ,'search_word':'%EB%B6%80%EB%8F%99%EC%82%B0 %EC%86%8C%EC%9C%A0%EA%B6%8C %EC%B7%A8%EB%93%9D%ED%98%84%ED%99%A9'
        ,'pagePerCount':'10'
        ,'search_order':'031003'
        ,'dts_prmm_ofr_yn':'Y'
        ,'returnUrl':''
        ,'search_regn_name':''
        ,'search_year':''
        ,'search_mon':''

    }

    headers={
        'Content-Type':'application/x-www-form-urlencoded'
        ,'-User-Agent':'PostmanRuntime/7.29.2'
        ,'Accept':'*/*'
        ,'Accept-Encoding':'gzip, deflate, br'
        ,'Connection':'keep-alive'
    }
# Out:
# /home/big/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.iros.go.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'dataList': [{'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 3,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 7,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 5,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 3,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 2,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 4,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 4,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 7,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 3,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 9,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 9,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 6,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 5,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 6,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 8,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 14,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 12,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 10,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 24,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 33,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 54,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 18,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 260,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 20,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 15,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 15,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 257,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 38,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 25,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 205,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 10,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 113,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 167,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 103,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 60,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 52,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 21,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 125,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 168,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 133,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 75,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 54,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 237,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '비법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '기타',
#    'enr_no_cls_cd': '12931'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 4,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 3,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '재외국민',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12912'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '재외국민',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12912'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '국가기관 및 지방자치단체',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '기타',
#    'enr_no_cls_cd': '12941'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 3,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 30,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 57,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 28,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 17,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 11,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 32,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 45,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 44,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 24,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 5,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 78,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강남구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 2,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 2,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 4,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 3,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 3,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 8,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 17,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 16,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 17,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 4,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 5,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 7,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 23,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 13,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 4,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 9,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 23,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 45,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 9,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 13,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 23,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 40,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 47,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 3,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 18,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 98,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 128,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 73,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 76,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 31,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 15,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 74,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 129,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 122,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 78,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 17,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 132,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '재외국민',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12912'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '국가기관 및 지방자치단체',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '기타',
#    'enr_no_cls_cd': '12941'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 13,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 25,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 29,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 34,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 8,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 9,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 11,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 49,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 40,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 9,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 155,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강동구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 2,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 3,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 2,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 5,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 2,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 5,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 4,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 9,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 27,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 16,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 10,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 10,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 5,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 16,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 19,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 10,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 16,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 10,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '비법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '기타',
#    'enr_no_cls_cd': '12931'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 28,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 40,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 37,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 35,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 18,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 12,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 23,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 35,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 48,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 208,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 15,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 57,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 70,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 68,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 17,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 13,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 10,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 48,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 64,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 82,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 41,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 20,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 35,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '비법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '기타',
#    'enr_no_cls_cd': '12931'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '재외국민',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12912'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 14,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '강북구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
# ...
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 26,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서대문구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 24,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '서대문구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 46,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '서대문구',
#    'enr_no_cls_cd_name': '비법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '기타',
#    'enr_no_cls_cd': '12931'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서대문구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서대문구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서대문구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서대문구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '토지',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서대문구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 1,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 1,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 2,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 2,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 2,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 3,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 11,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 17,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 12,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 8,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 5,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 8,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 15,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 11,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 6,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 4,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 13,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 34,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 37,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 25,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 7,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 46,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 17,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 7,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 66,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 14,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 20,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 21,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권보존',
#    'appl_nomprs_num': 8,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 21,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 171,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 356,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 182,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 96,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 38,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '0~18세(미성년자)',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 18,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 192,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 324,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 185,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 90,
#    'age': '60세~69세',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '여자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '내국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 68,
#    'age': '70세 이상',
#    'enr_no_cls_cd': '12911'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 451,
#    'age': '기타',
#    'enr_no_cls_cd': '12921'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '기타',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '비법인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '기타',
#    'enr_no_cls_cd': '12931'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '19세~29세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 7,
#    'age': '30세~39세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 6,
#    'age': '40세~49세',
#    'enr_no_cls_cd': '12913'},
#   {'cd_name': '집합건물',
#    'admin_regn1_name': '서울특별시',
#    'sex': '남자',
#    'admin_regn2_name': '서초구',
#    'enr_no_cls_cd_name': '외국인',
#    'bs_ym': '201701',
#    'rgs_aim_cd': '소유권이전',
#    'appl_nomprs_num': 2,
#    'age': '50세~59세',
#    'enr_no_cls_cd': '12913'},
#   ...]}

# %%
for i in range(1,10):
    res = requests.post(url,data=data,headers=headers, verify = False)
    res.json()
    file_name = 'gender_registration' + params['search_start_date_api'] + '.json'
    client.write(file_dir + file_name, res, encoding='utf-8')
# Out:
# /home/big/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.iros.go.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/big/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.iros.go.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/big/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.iros.go.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/big/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.iros.go.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/big/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.iros.go.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
